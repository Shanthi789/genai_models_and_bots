# %%
from google.colab import userdata
telegram_api_key=userdata.get('telegram')

# %%
telegram_api_key
# Out:
# '7718809267:AAFQPVSrrvnMcBy1lzCLNF8sJdU-0Th9eyQ'

# %%
import requests, time

# %%
url = f'https://api.telegram.org/bot{telegram_api_key}'

# %%
url
# Out:
# 'https://api.telegram.org/bot7718809267:AAFQPVSrrvnMcBy1lzCLNF8sJdU-0Th9eyQ'

# %%
r = requests.get(url+'/getUpdates')

# %%
r=r.json()

# %%
chat_id = r["result"][-1]["message"]["chat"]["id"]

# %%
chat_id
# Out:
# 1038878905

# %%
r=input("to telegram: ")
# Out:
# to telegram: hiii

# %%
r = requests.get(url+f'/sendMessage?chat_id={chat_id}&text={r}')

# %%
from google.colab import userdata
gemini_api = userdata.get('gemini')

# %%
gemini_api
# Out:
# 'AIzaSyBRGx27_7YzosWJloObAdCB7PeX4yKrjmw'

# %%
pip install google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=gemini_api)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
q
# Out:
# 'Quit'

# %%
r = model.generate_content(q)

# %%
import time

# %%
prev_msg_id = 0
time.sleep(5)
while True:
  req = requests.get(url+f'/sendMessage?chat_id={chat_id}&text={"question : (or type quit)"}')
  time.sleep(10)
  req = requests.get(url + f'/getUpdates')
  #r = requests.get(url+'/getUpdates?offset={last_update_id + 1}')
  data = req.json()
  if data["result"]:
    update = data["result"][-1]
    text = update["message"]["text"]
    msg_id = update["message"]["message_id"]
    print(text)
    if msg_id > prev_msg_id:
      if text == "Quit":
        break
      else:
        prev_msg_id = msg_id
        ans = model.generate_content(text)
        req = requests.get(url+f'/sendMessage?chat_id={chat_id}&text={ans.text}')
# Out:
# In 5 words Describe Singapore
# In 5 words Describe Singapore
# In 5 words Describe Singapore
# In 5 words Describe Singapore
# In 5 words Describe Bangkok
# Quit
